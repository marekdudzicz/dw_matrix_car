# %%
GITHUB_URL='https://{}@github.com/nowy112233/dw_matrix_car.git'.format(GITHUB_TOKEN)

# %%
cd "/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_two"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_two

# %%
# !git clone $GITHUB_URL

# %%
cd dw_matrix_car

# %%
# !mkdir data

# %%
cd data

# %%
# !echo -e "*\n!.gitignore" > .gitignore

# %%
# !git add .gitignore

# %%
# !curl https://www.dropbox.com/s/1voq5cp6myd8pqj/train.car_price.h5 -o car.h5

# %%
import pandas as pd

# %%
# !pip install --upgrade tables

# %%
df=pd.read_hdf('car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df.sample(5)
# Out:
#                                                breadcrumb  ...  car_id
# 38834                            [Osobowe, Lancia, Delta]  ...   38834
# 152255      [Osobowe, Saab, 9-3, Saab 9-3 II (2003-2011)]  ...  152255
# 54205   [Osobowe, Mercedes-Benz, Klasa E, E 43 AMG, Me...  ...   54205
# 52871   [Osobowe, BMW, Seria 3, 320, BMW Seria 3 F30 (...  ...   52871
# 76378          [Osobowe, BMW, X3, BMW X3 E83 (2003-2010)]  ...   76378
#
# [5 rows x 155 columns]

# %%
cd ..

# %%
# !git add day1_meta.ipynb

# %%
# !git commit -m "add car price"
# Out:
# [master ae17b55] add car price
#  2 files changed, 3 insertions(+)
#  create mode 100644 data/.gitignore
#  create mode 100644 day1_meta.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 3.96 KiB | 676.00 KiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
